# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Dataset URL: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# License(s): DbCL-1.0
# ...
#  89% 59.0M/66.0M [00:00<00:00, 80.5MB/s]
# 100% 66.0M/66.0M [00:00<00:00, 75.9MB/s]

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler

# Generate synthetic dataset (for demonstration purposes)
def generate_synthetic_data(n_samples=1000):
    np.random.seed(42)
    data = {
        'transaction_amount': np.random.rand(n_samples) * 1000,
        'transaction_time': np.random.randint(0, 24, n_samples),
        'location_difference': np.random.rand(n_samples) * 100,
        'previous_fraud_count': np.random.randint(0, 5, n_samples),
        'is_fraud': np.random.choice([0, 1], n_samples, p=[0.95, 0.05])
    }
    return pd.DataFrame(data)

# Load synthetic data (replace this with actual data loading if you have a dataset)
data = generate_synthetic_data()

# Display the first few rows
print("Dataset Sample:")
display(data.head())

# Separate features and labels
X = data.drop('is_fraud', axis=1)
y = data['is_fraud']

# Standardize the features for better model performance
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Initialize and train the model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print results
print(f"Accuracy: {accuracy * 100:.2f}%")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)
# Out:
# Dataset Sample:
#    transaction_amount  transaction_time  location_difference  \
# 0          374.540119                14            51.567943
# 1          950.714306                11            91.939197
# 2          731.993942                15            49.696348
# 3          598.658484                23            99.215801
# 4          156.018640                18            85.142496
#
#    previous_fraud_count  is_fraud
# 0                     0         1
# 1                     3         0
# 2                     4         0
# 3                     4         0
# 4                     4         0
# Accuracy: 94.33%
# Confusion Matrix:
# [[283   1]
#  [ 16   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       284
#            1       0.00      0.00      0.00        16
#
#     accuracy                           0.94       300
#    macro avg       0.47      0.50      0.49       300
# ...
